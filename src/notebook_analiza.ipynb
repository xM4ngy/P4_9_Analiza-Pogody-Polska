# %% [markdown]
# # Analiza pogody w Polsce
# Notebook pomocniczy do odtworzenia analizy korelacji.

# %%
import pandas as pd
df = pd.read_csv('../data/pogoda_polska.csv', encoding='utf-8-sig')
df.head()

# %%
import sys
sys.path.append('..')
from src.analiza import analyze_weather
corr = analyze_weather('../data/pogoda_polska.csv', '../outputs/AnalizaZdjecie.png', '../outputs/macierz_korelacji.csv')
corr
